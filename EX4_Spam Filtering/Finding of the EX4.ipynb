# %% [markdown]
# Finding of the EX4

# %% [markdown]
# In this exercise , i built spam filter using the dataset provided by  Apache SpamAssassin’s public datasets.
# first i had to clean the emails and convert them into numerical features using TF-IDF so machine learning models could process the text.
#
# Three models were used :
# 1. Naive Bayes
# 2. Logistic Regression
# 3. SGDClassifier.
# Below are results with 1,2,3 orders

# %% [markdown]
# Accuracy : 0.9434276206322796
# Precision: 1.0
# Recall   : 0.66
# F1       : 0.7951807228915663
# Confusion matrix:
# [[501   0]
#  [ 34  66]]

# %% [markdown]
# Accuracy : 0.9600665557404326
# Precision: 1.0
# Recall   : 0.76
# F1       : 0.8636363636363636
# Confusion matrix:
#  [[501   0]
#  [ 24  76]]

# %% [markdown]
# Accuracy : 0.9850249584026622
# Precision: 1.0
# Recall   : 0.91
# F1       : 0.9528795811518325
# Confusion matrix:
#  [[501   0]
#  [  9  91]

# %% [markdown]
# all of them have precision of 1.0, meaning that there were no FP produced. But if u look at result , there were 34, 24, and 9 missed spams from models respectively. They all avoided false alarm and only marked spam with 100% confidence . They all had perfect precision , but it makes me question the reliability of the models
